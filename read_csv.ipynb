# %%
import pandas as pd
csv ='C:/Users/mhsilva/Documents/Workspace/acoes/data/work/carteira_fase_06.csv'
pd.read_csv('C:/Users/mhsilva/Documents/Workspace/acoes/data/work/carteira_fase_06.csv').sort_values('VALOR_ATUAL_INVESTIDO',ascending=False).head(100)
# Out:
#                       EMPRESA SIMBOLO  QUANTIDADE  VALOR_MEDIO_PAGO  \
# 3              WALT_DISNEY_CO     DIS     1.70593             62.27
# 6          META_PLATFORMS_INC    META     0.72796            201.47
# 7              MICROSOFT_CORP    MSFT     0.27021            292.70
# 4         ELECTRONIC_ARTS_INC      EA     0.12200            131.31
# 5                ALPHABET_INC   GOOGL     0.04200             90.95
# 2  BERKSHIRE_HATHAWAY_INC_DEL   BRK.B     0.00790            231.65
# 8                QUALCOMM_INC    QCOM     0.01610            128.57
# 9                   TESLA_INC    TSLA     0.00810            196.30
# 1              AMAZON.COM_INC    AMZN     0.01400            152.86
# 0                   APPLE_INC    AAPL     0.00550            141.82
#
#    VALOR_ATUAL  VALOR_ATUAL_INVESTIDO  POSICAO_ATUAL  META  DEFICT  OBJETIVO  \
# 3       106.44                 181.58          52.66   3.0   49.66  DIMINUIR
# ...
